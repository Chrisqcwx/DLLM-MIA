# %%
import os
for a in os.listdir("."):
    if "LLaDA" in a:
        print(f'"{a}" \\')
# Out:
# "LLaDA-8B-Base-pretrained-ag_news.yaml" \
# "LLaDA-8B-Base-pretrained-mimir-github.yaml" \
# "LLaDA-8B-Base-pretrained-cosmopedia-auto_math_text.yaml" \
# "LLaDA-8B-Base-pretrained-cosmopedia-web_samples_v2.yaml" \
# "LLaDA-8B-Base-pretrained-wikitext-wikitext-103-v1.yaml" \
# "LLaDA-8B-Base-pretrained-mimir-pile_cc.yaml" \
# "LLaDA-8B-Base-pretrained-xsum.yaml" \
# "LLaDA-8B-Base-pretrained-mimir-pubmed_central.yaml" \
# "LLaDA-8B-Base-pretrained-mimir-arxiv-lora.yaml" \
# "LLaDA-8B-Base-pretrained-mimir-arxiv.yaml" \
# "LLaDA-8B-Base-pretrained-cosmopedia-stanford.yaml" \
# "LLaDA-8B-Base-pretrained-cosmopedia-khanacademy.yaml" \
# "LLaDA-8B-Base-pretrained-cosmopedia-stories.yaml" \
